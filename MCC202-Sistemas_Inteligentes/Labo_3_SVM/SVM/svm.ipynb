# %% [markdown]
# # <b>Máquina de Vectores de Soporte<b/>

# %% [markdown]
# ## <b>I. Preguntas de Teoría<b/>

# %% [markdown]
# <b>Grafique S, H1, H2, H3 y H4:<b/>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# !pip install ipympl
# !conda install nodejs
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install jupyter-matplotlib

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for x, y, z in [(1,6,-1), (4,9,-1), (4,6,-1)]:
    xs = x
    ys = y
    zs = z
    ax.scatter(xs, ys, zs, c='r', marker='o')
    
for x, y, z in [(5,1,1), (9,5,1), (9,1,1)]:
    xs = x
    ys = y
    zs = z
    ax.scatter(xs, ys, zs, c='b', marker='o')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = X-1
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

# Z, X = np.meshgrid(np.arange(-5, 10, .1), np.arange(-5, 10, .1))
# Y = (2/7)*X+32/7
# ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

# Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
# Y = X-1
# ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

# Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
# Y = (2/7)*X-32/7
# ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H1')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = X-1
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H1')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = (2/7)*X+32/7
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H2')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = X-1
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H3')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = (2/7)*X-32/7
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H4')

plt.show()

# %% [markdown]
# <b>Grafique N y H5==H1:<b/>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# !pip install ipympl
# !conda install nodejs
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install jupyter-matplotlib

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for x, y, z in [(1,6,-1), (4,9,-1), (4,6,-1), (2,2,-1), (3,1,-1)]:
    xs = x
    ys = y
    zs = z
    ax.scatter(xs, ys, zs, c='r', marker='o')
    
for x, y, z in [(5,1,1), (9,1,1), (0,3,1)]:
    xs = x
    ys = y
    zs = z
    ax.scatter(xs, ys, zs, c='b', marker='o')
    
Z, X = np.meshgrid(np.arange(0, 10, .1), np.arange(0, 10, .1))
Y = X-1
ax.plot_surface(X, Y, Z, rstride=10, cstride=10)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('H5')

plt.show()

# %% [markdown]
# <br/>

# %% [markdown]
# ## <b>III. Implementación<b/>

# %% [markdown]
# <br/>

# %% [markdown]
# ### <b>Usando Scikit-learn de Python, implemente una SVM que clasifique el conjunto de datos ¡Por definir!<b/>

# %% [markdown]
# Como no se ha incluído el dataset, he propuesto trabajar el presente ejercicio con el siguiente dataset https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Asignar columnas al Dataset para su posterior lectura
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# Lectura del Dataset usando pandas
irisdata = pd.read_csv(url, names=colnames)

# %% [markdown]
# <b>Explorando los datos<b/>

# %%
# Dimensiones del Dataset
irisdata.shape
# Out:
# (150, 5)

# %%
# Descripción del Dataset
irisdata.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# <b>Preprocesamiento<b/>

# %%
# Separación de las columnas del dataset para crear los valores de entrada y el valor de salida
X = irisdata.drop('Class', axis=1)
y = irisdata['Class']

# %%
from sklearn.model_selection import train_test_split
# Separación del dataset en valores de entranemiento y testeo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC
# Elección del Kernel: linear
svclassifier = SVC(kernel='linear')
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test,y_pred))
# Creación de reporte de resultados
print(classification_report(y_test,y_pred))
# Out:
# [[ 6  0  0]
#  [ 0 12  0]
#  [ 0  0 12]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         6
# Iris-versicolor       1.00      1.00      1.00        12
#  Iris-virginica       1.00      1.00      1.00        12
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# <br/>

# %% [markdown]
# ### <b>Experimente y muestre resultados usando diferentes valores para los parámetros de los kernels: linear, polinomial, gaussiano y el parámetro C. Los resultados deben ser mostrados en el documento pdf.<b/>

# %% [markdown]
# Como no se ha incluído el dataset, he propuesto trabajar el presente ejercicio con el siguiente dataset https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %% [markdown]
# <br/>

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Asignar columnas al Dataset para su posterior lectura
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# Lectura del Dataset usando pandas
irisdata = pd.read_csv(url, names=colnames)

# %% [markdown]
# <b>Explorando los datos<b/>

# %%
# Descripción del Dataset
irisdata.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# <b>Preprocesamiento<b/>

# %%
# Separación de las columnas del dataset para crear los valores de entrada y el valor de salida
X = irisdata.drop('Class', axis=1)  
y = irisdata['Class']

# %%
# Separación del dataset en valores de entranemiento y testeo
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %% [markdown]
# ### <b>Lineal con C=0.5<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC  
# Elección del Kernel: linear Y parámetro C=0.5
svclassifier = SVC(kernel='linear', C=0.5)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test,y_pred))
# Creación de reporte de resultados
print(classification_report(y_test,y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Lineal con C=1<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC  
# Elección del Kernel: linear Y parámetro C=1.0
svclassifier = SVC(kernel='linear', C=1.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test,y_pred))
# Creación de reporte de resultados
print(classification_report(y_test,y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  1  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.89      0.94         9
#
#     avg / total       0.97      0.97      0.97        30

# %% [markdown]
# ### <b>Lineal con C=2<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC  
# Elección del Kernel: linear Y parámetro C=2.0
svclassifier = SVC(kernel='linear', C=2.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=2.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test,y_pred))
# Creación de reporte de resultados
print(classification_report(y_test,y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Lineal con C=5<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC  
# Elección del Kernel: linear Y parámetro C=5.0
svclassifier = SVC(kernel='linear', C=5.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=5.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test,y_pred))
# Creación de reporte de resultados
print(classification_report(y_test,y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  1  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.89      0.94         9
#
#     avg / total       0.97      0.97      0.97        30

# %% [markdown]
# ### <b>Polinomial con C=0.5<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC 
# Elección del Kernel: Poly Y parámetro C=0.5
svclassifier = SVC(kernel='poly', degree=8, C=0.5)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=8, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Polinomial con C=1<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC 
# Elección del Kernel: Poly Y parámetro C=1.0
svclassifier = SVC(kernel='poly', degree=8, C=1.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=8, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Polinomial con C=2<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC 
# Elección del Kernel: Poly Y parámetro C=2.0
svclassifier = SVC(kernel='poly', degree=8, C=2.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=2.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=8, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Polinomial con C=5<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC 
# Elección del Kernel: Poly Y parámetro C=5.0
svclassifier = SVC(kernel='poly', degree=8, C=5.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=5.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=8, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Gaussiano con C=0.5<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC
# Elección del Kernel: rbf
svclassifier = SVC(kernel='rbf', C=0.5)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Gaussiano con C=1.0<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC
# Elección del Kernel: rbf
svclassifier = SVC(kernel='rbf', C=1.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  1  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.89      0.94         9
#
#     avg / total       0.97      0.97      0.97        30

# %% [markdown]
# ### <b>Gaussiano con C=2.0<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC
# Elección del Kernel: rbf
svclassifier = SVC(kernel='rbf', C=2.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=2.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30

# %% [markdown]
# ### <b>Gaussiano con C=5.0<b/>

# %% [markdown]
# <b>Entrenamiento<b/>

# %%
from sklearn.svm import SVC
# Elección del Kernel: rbf
svclassifier = SVC(kernel='rbf', C=5.0)
# Ejecución del entrenamiento
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=5.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# <b>Predicción y Validación<b/>

# %%
# Predicción usando los valores de testeo
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
# Creación de la matriz de confusión
print(confusion_matrix(y_test, y_pred))
# Creación de reporte de resultados
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         9
#
#     avg / total       1.00      1.00      1.00        30
